# %%
# add .. to PYTHONPATH
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

from telemetry import Telemetry

# %%
t = Telemetry()
t.set_filter({'session_id': 1718114100})
t.get_telemetry_df().head()
# Out:
#     result  table                           _start  \
# 0  _result      0 2024-04-19 19:28:45.448238+00:00
# 1  _result      0 2024-04-19 19:28:45.448238+00:00
# 2  _result      0 2024-04-19 19:28:45.448238+00:00
# 3  _result      0 2024-04-19 19:28:45.448238+00:00
# 4  _result      0 2024-04-19 19:28:45.448238+00:00
#
#                              _stop                            _time  \
# 0 2024-06-18 19:28:45.448238+00:00 2024-06-11 15:55:01.812144+00:00
# 1 2024-06-18 19:28:45.448238+00:00 2024-06-11 15:55:01.921869+00:00
# 2 2024-06-18 19:28:45.448238+00:00 2024-06-11 15:55:02.027754+00:00
# 3 2024-06-18 19:28:45.448238+00:00 2024-06-11 15:55:02.142110+00:00
# 4 2024-06-18 19:28:45.448238+00:00 2024-06-11 15:55:02.250231+00:00
#
#              CarModel CurrentLap             GameName   SessionId  \
# 0  VW Polo R WRC 2016          0  Richard Burns Rally  1718114100
# 1  VW Polo R WRC 2016          0  Richard Burns Rally  1718114100
# ...

# %%
t.set_filter({'game': True})
t.get_data_df().head()
# Out:
#                          name
# 0                     iRacing
# 1                    RaceRoom
# 2  Assetto Corsa Competizione
# 3      Assetto Corsa (64 bit)
# 4             Automobilista 2
